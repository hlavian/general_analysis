# %%
from pathlib import Path
import matplotlib.pyplot as plt 
import tifffile as tiff
import numpy as np

# %%
ref_path = Path(r"Z:\Hagar\mpin_zfish_1um_v1.1")

# %%
ref = tiff.imread(ref_path / 'reference.tiff')

# %%
fig, ax = plt.subplots(1,1, figsize = (8,8))
ax.imshow(np.sum(ref, axis=1), cmap='gray_r', vmin=3000)
ax.axis('off')

# %%
fig.savefig(ref_path / 'ref_image.pdf', dpi=720)
