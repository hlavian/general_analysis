# %%
# %matplotlib widget

# %%
import numpy as np
from pathlib import Path
import flammkuchen as fl
import napari
import matplotlib.pyplot as plt

from bg_atlasapi.bg_atlas import BrainGlobeAtlas
from bg_space import AnatomicalSpace
from quickdisplay import *

from fimpylab.core.twop_experiment import TwoPExperiment

# %%
# %gui qt5

# %%
import tifffile as tiff

# %%
master = Path(r"Z:\Hagar\s11\e0040")
fish_list = list(master.glob("*_v13*"))
ref_fish = Path(r"Z:\Hagar\s11\e0040\240305_f0_v13\registration")

# %%
#Define morphing space...
morphing_as = AnatomicalSpace('rai', resolution=(0.3,0.3,1))

# %%
# load tuning map of ref fish
ref_tuning_map = fl.load(ref_fish / "ref_mapped.h5")

#exp_ref = TwoPExperiment(ref_fish)
#ref_res = exp_ref.resolution
ref_res = (0.3,0.3,1)
ref_as = AnatomicalSpace('ipl', resolution=ref_res, shape=ref_tuning_map.shape[:3])

# %%
np.shape(ref_tuning_map[:,:,:])

# %%
#... and transform references to morphing space
ref_mapped = np.zeros((413, 413, 100, 3))
#for i in range(3):
#    ref_mapped[:,:,:,i] = ref_as.map_stack_to(morphing_as, ref_tuning_map[:,:,:,i])

# %%
num_planes, n_x, n_y = np.shape(ref_mapped)[:3]
num_fish = len(fish_list)
tuning_maps_all = np.zeros((num_fish, num_planes, n_x, n_y, 3))

# %%
count = 0
for fish in fish_list:
    print(fish)
    
    if fish is not ref_fish:
        path = fish / "registration" 
        
        
        # load tuning map
        transform_mat = fl.load(path / "initial_transform_mapped.h5")
        try:
            mov_stack = fl.load(fish / "tuning_map_new_90.h5")
        except:
            mov_stack = fl.load(fish / "tuning_map_90_fixed_2024.h5")
        
        exp_mov = TwoPExperiment(fish)
        mov_res = exp_mov.resolution
        
        # morph tuning map
        mov_as = AnatomicalSpace('ipl', resolution=mov_res, shape=mov_stack.shape)
        
        mov_mapped_tmp = mov_as.map_stack_to(morphing_as, mov_stack[:,:,:,0])
        
        mov_mapped = np.zeros((np.shape(mov_mapped_tmp)[0], np.shape(mov_mapped_tmp)[1], np.shape(mov_mapped_tmp)[2], 3))
        
        transformed = np.zeros(ref_mapped.shape)
        
        for i in range(3):
            mov_mapped[:,:,:,i] = mov_as.map_stack_to(morphing_as, mov_stack[:,:,:,i])
            
            tmp = map_affine(mov_mapped[:,:,:,i], transform_mat, ref_mapped.shape[:3])
            
            min_val = np.nanmin(tmp)
            tmp -= min_val
            
            max_val = np.nanmax(tmp)
            tmp /= max_val
            
            transformed[:,:,:,i] = tmp * 255
        
        tuning_maps_all[count] = transformed
        
        d = {'tuning_map_morphed': transformed}
        fl.save(fish / 'tuning_map_morphed.h5', d)
    else:
        print("loading ref fish")
        tuning_maps_all[count] = ref_mapped
    count += 1

# %%
ref_mapped.shape

# %%
viewer = napari.view_image(tuning_maps_all[5,:,:,:,0], colormap='Reds')
viewer.add_image(tuning_maps_all[5,:,:,:,1], colormap='Greens', blending='additive')
viewer.add_image(tuning_maps_all[5,:,:,:,2], colormap='Blues', blending='additive')

# %%
tuning_maps_all = tuning_maps_all.astype('int32')

# %%
tuning_map_avg = np.nanmean(tuning_maps_all, axis=0).astype('int32')

# %%
tuning_maps_all = fl.load(master / 'tuning_map_morphed_all.h5')['tuning_map_all']
tuning_map_avg = np.nanmedian(tuning_maps_all, axis=0).astype('int32')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-495332c4a5b9> in <module>
# ----> 1 tuning_maps_all = fl.load(master / 'tuning_map_morphed_all.h5')['tuning_map_all']
#       2 tuning_map_avg = np.nanmedian(tuning_maps_all, axis=0).astype('int32')
#
# ~\anaconda3\envs\rplab\lib\site-packages\flammkuchen\hdf5io.py in load(path, group, sel, unpack)
#     689     """
#     690     path = str(path)  # Allows for Path objects to be used
# --> 691     with tables.open_file(path, mode='r') as h5file:
#     692         pathtable = {}  # dict to keep track of objects already loaded
#     693         if group is not None:
#
# ~\anaconda3\envs\rplab\lib\site-packages\tables\file.py in open_file(filename, mode, title, root_uep, filters, **kwargs)
#     298
#     299     # Finally, create the File instance, and return it
# --> 300     return File(filename, mode, title, root_uep, filters, **kwargs)
#     301
#     302
#
# ~\anaconda3\envs\rplab\lib\site-packages\tables\file.py in __init__(self, filename, mode, title, root_uep, filters, **kwargs)
#     748
#     749         # Now, it is time to initialize the File extension
# --> 750         self._g_new(filename, mode, **params)
#     751
#     752         # Check filters and set PyTables format version for new files.
#
# ~\anaconda3\envs\rplab\lib\site-packages\tables\hdf5extension.pyx in tables.hdf5extension.File._g_new()
#
# ~\anaconda3\envs\rplab\lib\site-packages\tables\utils.py in check_file_access(filename, mode)
#     141         # The file should be readable.
#     142         if not os.access(path, os.F_OK):
# --> 143             raise OSError(f"``{path}`` does not exist")
#     144         if not path.is_file():
#     145             raise OSError(f"``{path}`` is not a regular file")
#
# OSError: ``\\portulab.synology.me\data\Hagar\s11\e0040\tuning_map_morphed_all.h5`` does not exist

# %%
planes = [25, 30, 35, 40, 45, 50, 55, 60]
n_planes = len(planes)
n_col = 4
fig, ax = plt.subplots(2, n_col, figsize=(12,6))

for i in range(n_planes):
    r = i // n_col
    c = np.mod(i, n_col)
    ax[r, c].imshow(np.rot90(tuning_map_avg[:,:,planes[i]], 3))
    ax[r, c].axis('off')
    
    ax[r,c].set_xlim(30, 380)
    ax[r,c].set_ylim(400, 50)

# %%
fig.savefig(master / "average morphed ipns only v13.jpg", dpi=300)
fig.savefig(master / "average morphed ipns only v13.pdf", dpi=300)

# %%
viewer2 = napari.view_image(tuning_map_avg[:,:,:])

# %%
viewer2.add_image(tuning_map_avg[:,:,:,1], colormap='Greens', blending='additive')
viewer2.add_image(tuning_map_avg[:,:,:,2], colormap='Blues', blending='additive')

# %%
np.shape(tuning_map_avg)

# %%
d = {'tuning_map_avg': tuning_map_avg,
     'tuning_map_all': tuning_maps_all
}
fl.save(master / 'tuning_map_morphed_all.h5', d)
