# %%
#%gui qt
import napari
from pathlib import Path
import tifffile
from napari_animation import AnimationWidget
from split_dataset import SplitDataset
import numpy as np
from naparimovie import Movie
from scipy import ndimage
# %gui qt5

# %%
fish_young = Path(r"Z:\Hagar\development\dendra anatomy several days\231107_f24_4dpf")
fish_old = Path(r"Z:\Hagar\development\dendra anatomy juvenile\231124_f9_21dpf")

# %%
anatomy_young = tifffile.imread(fish_young / "anatomy.tif")
anatomy_old = tifffile.imread(fish_old / "anatomy.tif")

# %%
viewer = napari.view_image(anatomy_young[20:], scale=(1, 1, 1), colormap='gray_r')
viewer.add_image(anatomy_old[0:], scale=(1, 1, 1), colormap='gray_r')

# %%
animation_widget = AnimationWidget(viewer)
viewer.window.add_dock_widget(animation_widget, area='right')
