# %%
# %matplotlib widget

# %%
from pathlib import Path
import numpy as np
import flammkuchen as fl
import matplotlib.pyplot as plt

# %%
master = Path(r"\\Funes\Shared\experiments\E0020_random_coherences\v27_imaging")
all_fish = list(master.glob("*_f*/*tail_segments_for_napari*"))
len(all_fish)

# %%
fish = all_fish[93]
beh_data = fl.load(fish)[0]
print(fish)

# %%
fish = all_fish[93]
fish_dir = fish.parent
beh_data = fl.load(fish)[0]
tail_pos = beh_data['tail_positive']
tail_neg = beh_data['tail_negative']

num_trials, num_segments, len_segment = np.shape(tail_neg)

new_len=len_segment
segment_neg = tail_neg[:, :, 0:new_len]
segment_pos = tail_pos[:, :, 0:new_len]

fig0, ax0 = plt.subplots(3, 3, figsize=(5, 6), sharex=True, sharey=True)
# row 1 - forward beginning 
# row 2 - training 
# row 3 - post training 
title_set = ['Forward beginning', 'Training', 'Forward post training']

for trial in range(0, 10):
    for i in range(1, num_segments):

        tmp_tracks = np.zeros((len_segment, 3))
        fish_id = np.ones((len_segment)) * (i + 1)  *  10
        x = np.cos(segment_pos[trial, i] - segment_pos[0, 0])
        y = np.sin(segment_pos[trial, i] - segment_pos[0, 0])
        tmp_tracks[:, 1] =  x * -fish_id# value of theta
        tmp_tracks[:, 2] = y * 20# height of segments 

        ax0[0, 0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')
        ax0[0, 1].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')

        tmp_tracks = np.zeros((len_segment, 3))
        fish_id = np.ones((len_segment)) * (i + 1)  *  10
        x = np.cos(segment_neg[trial, i] - segment_neg[0, 0])
        y = np.sin(segment_neg[trial, i] - segment_neg[0, 0])
        tmp_tracks[:, 1] =  x * -fish_id# value of theta
        tmp_tracks[:, 2] = y * 20# height of segments 

        ax0[0, 0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')
        ax0[0, 2].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')


t1 = 10
for trial in range(t1, t1+60):
    for i in range(1, num_segments):

        tmp_tracks = np.zeros((len_segment, 3))
        fish_id = np.ones((len_segment)) * (i + 1)  *  10
        x = np.cos(segment_pos[trial, i] - segment_pos[0, 0])
        y = np.sin(segment_pos[trial, i] - segment_pos[0, 0])
        tmp_tracks[:, 1] =  x * -fish_id# value of theta
        tmp_tracks[:, 2] = y * 20# height of segments 

        ax0[1, 0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')
        ax0[1, 1].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')


        tmp_tracks = np.zeros((len_segment, 3))
        fish_id = np.ones((len_segment)) * (i + 1)  *  10
        x = np.cos(segment_neg[trial, i] - segment_neg[0, 0])
        y = np.sin(segment_neg[trial, i] - segment_neg[0, 0])
        tmp_tracks[:, 1] =  x * -fish_id# value of theta
        tmp_tracks[:, 2] = y * 20# height of segments 

        ax0[1, 0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')
        ax0[1, 2].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')

for trial in range(70, 80):
    for i in range(1, num_segments):

        tmp_tracks = np.zeros((len_segment, 3))
        fish_id = np.ones((len_segment)) * (i + 1)  *  10
        x = np.cos(segment_pos[trial, i] - segment_pos[0, 0])
        y = np.sin(segment_pos[trial, i] - segment_pos[0, 0])
        tmp_tracks[:, 1] =  x * -fish_id# value of theta
        tmp_tracks[:, 2] = y * 20# height of segments 

        ax0[2, 0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')
        ax0[2, 1].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')


        tmp_tracks = np.zeros((len_segment, 3))
        fish_id = np.ones((len_segment)) * (i + 1)  *  10
        x = np.cos(segment_neg[trial, i] - segment_neg[0, 0])
        y = np.sin(segment_neg[trial, i] - segment_neg[0, 0])
        tmp_tracks[:, 1] =  x * -fish_id# value of theta
        tmp_tracks[:, 2] = y * 20# height of segments 

        ax0[2, 0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')
        ax0[2, 2].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')

for i in range(3):
    for j in range(3):
        ax0[j, i].spines['right'].set_visible(False)
        ax0[j, i].spines['top'].set_visible(False)
    ax0[i, 1].set_title(title_set[i])

fig0.savefig(fish_dir / 'left_right_turning_220222')

# %%
for fish in all_fish[120:130]:
    plt.close()
    fish_dir = fish.parent
    beh_data = fl.load(fish)[0]
    tail_pos = beh_data['tail_positive']
    tail_neg = beh_data['tail_negative']

    num_trials, num_segments, len_segment = np.shape(tail_neg)
    
    if num_trials > 70:
        new_len=len_segment
        segment_neg = tail_neg[:, :, 0:new_len]
        segment_pos = tail_pos[:, :, 0:new_len]

        fig0, ax0 = plt.subplots(3, 3, figsize=(5, 6), sharex=True)#, sharey=True)
        # row 1 - forward beginning 
        # row 2 - training 
        # row 3 - post training 
        title_set = ['Forward beginning', 'Training', 'Forward post training']

        for trial in range(0, 10):
            for i in range(1, num_segments):

                tmp_tracks = np.zeros((len_segment, 3))
                fish_id = np.ones((len_segment)) * (i + 1)  *  10
                x = np.cos(segment_pos[trial, i] - segment_pos[0, 0])
                y = np.sin(segment_pos[trial, i] - segment_pos[0, 0])
                tmp_tracks[:, 1] =  x * -fish_id# value of theta
                tmp_tracks[:, 2] = y * 10# height of segments 

                ax0[0, 0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')
                ax0[0, 1].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')

                tmp_tracks = np.zeros((len_segment, 3))
                fish_id = np.ones((len_segment)) * (i + 1)  *  10
                x = np.cos(segment_neg[trial, i] - segment_neg[0, 0])
                y = np.sin(segment_neg[trial, i] - segment_neg[0, 0])
                tmp_tracks[:, 1] =  x * -fish_id# value of theta
                tmp_tracks[:, 2] = y * 10# height of segments 

                ax0[0, 0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')
                ax0[0, 2].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')


        t1 = 10
        for trial in range(t1, t1+60):
            for i in range(1, num_segments):

                tmp_tracks = np.zeros((len_segment, 3))
                fish_id = np.ones((len_segment)) * (i + 1)  *  10
                x = np.cos(segment_pos[trial, i] - segment_pos[0, 0])
                y = np.sin(segment_pos[trial, i] - segment_pos[0, 0])
                tmp_tracks[:, 1] =  x * -fish_id# value of theta
                tmp_tracks[:, 2] = y * 10# height of segments 

                ax0[1, 0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')
                ax0[1, 1].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')


                tmp_tracks = np.zeros((len_segment, 3))
                fish_id = np.ones((len_segment)) * (i + 1)  *  10
                x = np.cos(segment_neg[trial, i] - segment_neg[0, 0])
                y = np.sin(segment_neg[trial, i] - segment_neg[0, 0])
                tmp_tracks[:, 1] =  x * -fish_id# value of theta
                tmp_tracks[:, 2] = y * 10# height of segments 

                ax0[1, 0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')
                ax0[1, 2].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')

        for trial in range(70, 80):
            for i in range(1, num_segments):

                tmp_tracks = np.zeros((len_segment, 3))
                fish_id = np.ones((len_segment)) * (i + 1)  *  10
                x = np.cos(segment_neg[trial, i] - segment_pos[0, 0])
                y = np.sin(segment_neg[trial, i] - segment_pos[0, 0])
                tmp_tracks[:, 1] =  x * -fish_id# value of theta
                tmp_tracks[:, 2] = y * 10# height of segments 

                ax0[2, 0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')
                ax0[2, 1].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')


                tmp_tracks = np.zeros((len_segment, 3))
                fish_id = np.ones((len_segment)) * (i + 1)  *  10
                x = np.cos(segment_pos[trial, i] - segment_neg[0, 0])
                y = np.sin(segment_pos[trial, i] - segment_neg[0, 0])
                tmp_tracks[:, 1] =  x * -fish_id# value of theta
                tmp_tracks[:, 2] = y * 10# height of segments 

                ax0[2, 0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')
                ax0[2, 2].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')

        for i in range(3):
            for j in range(3):
                ax0[j, i].spines['right'].set_visible(False)
                ax0[j, i].spines['top'].set_visible(False)
            ax0[i, 1].set_title(title_set[i])

        fig0.savefig(fish_dir / 'left_right_turning_220222')

# %%
np.shape(segment)

# %%
viewer = napari.Viewer()
t = np.arange(len_segment) / 10
color_list = ['r', '#aa0000', '#ff7980', 'crimson', 'salmon', 'tomato', 'r', '#aa0000', '#ff7980', 'crimson', 'salmon', 'tomato', 'r', '#aa0000', '#ff7980', 'crimson', 'salmon', 'tomato', 'r', '#aa0000', '#ff7980', 'crimson', 'salmon', 'tomato',
             'r', '#aa0000', '#ff7980', 'crimson', 'salmon', 'tomato', 'r', '#aa0000', '#ff7980', 'crimson', 'salmon', 'tomato', 'r', '#aa0000', '#ff7980', 'crimson', 'salmon', 'tomato', 'r', '#aa0000', '#ff7980', 'crimson', 'salmon', 'tomato']

t1 = 21
for trial in range(t1, t1+40):
    tracks_data = np.zeros((len_segment, 3))
    for i in range(1, num_segments):

        tmp_tracks = np.zeros((len_segment, 3))
        fish_id = np.ones((len_segment)) * (i + 1)  *  10
        x = np.cos(segment[trial, i] - segment[0, 0])
        y = np.sin(segment[trial, i] - segment[0, 0])
        tmp_tracks[:, 0] = t
        tmp_tracks[:, 1] = fish_id + x # value of theta
        tmp_tracks[:, 2] = y * 10# height of segments 

        tracks_data = np.append(tracks_data, tmp_tracks, axis=0)

# %%
fig0, ax0 = plt.subplots(1, 3, figsize=(5, 3), sharex=True, sharey=True)
t1 = 21
for trial in range(t1, t1+40):
    for i in range(1, num_segments):

        tmp_tracks = np.zeros((len_segment, 3))
        fish_id = np.ones((len_segment)) * (i + 1)  *  10
        x = np.cos(segment_pos[trial, i] - segment_pos[0, 0])
        y = np.sin(segment_pos[trial, i] - segment_pos[0, 0])
        tmp_tracks[:, 1] =  x * -fish_id# value of theta
        tmp_tracks[:, 2] = y * 10# height of segments 

        ax0[0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')
        ax0[1].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')


        tmp_tracks = np.zeros((len_segment, 3))
        fish_id = np.ones((len_segment)) * (i + 1)  *  10
        x = np.cos(segment_neg[trial, i] - segment_neg[0, 0])
        y = np.sin(segment_neg[trial, i] - segment_neg[0, 0])
        tmp_tracks[:, 1] =  x * -fish_id# value of theta
        tmp_tracks[:, 2] = y * 10# height of segments 

        ax0[0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')
        ax0[2].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')

for i in range(3):
    ax0[i].spines['right'].set_visible(False)
    ax0[i].spines['top'].set_visible(False)
    
fig0.save(fish)

# %%
fig1, ax1 = plt.subplots(1, 3, figsize=(5, 3), sharex=True, sharey=True)
t1 = 21
for trial in range(t1, t1+40):
    for i in range(len_segment):

        tmp_tracks = np.zeros((num_segments, 3))
        fish_id = np.ones((num_segments)) * (i + 1)  *  10
        x = np.cos(segment_pos[trial, :, i] - segment_pos[0, :, 0])
        y = np.sin(segment_pos[trial, :, i] - segment_pos[0, :, 0])
        tmp_tracks[:, 1] =  x * -fish_id# value of theta
        tmp_tracks[:, 2] = y * 10# height of segments 

        ax1[0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')
        ax1[1].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='g')


        tmp_tracks = np.zeros((num_segments, 3))
        fish_id = np.ones((num_segments)) * (i + 1)  *  10
        x = np.cos(segment_neg[trial, :, i] - segment_neg[0, :, 0])
        y = np.sin(segment_neg[trial, :, i] - segment_neg[0, :, 0])
        tmp_tracks[:, 1] =  x * -fish_id# value of theta
        tmp_tracks[:, 2] = y * 10# height of segments 

        ax1[0].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')
        ax1[2].plot( tmp_tracks[:, 2],  tmp_tracks[:, 1], c='r')

for i in range(3):
    ax1[i].spines['right'].set_visible(False)
    ax1[i].spines['top'].set_visible(False)

# %%
np.shape(segment_pos)
